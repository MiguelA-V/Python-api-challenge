# %%
#!jupyter nbextension enable --py --sys-prefix widgetsnbextension
#!pip install gmaps
#jupyter nbextension enable --py --sys-prefix gmaps
#!jupyter nbextension enable --py --sys-prefix widgetsnbextension

# !{sys.executable}  -m jupyter nbextension enable --py gmaps
# !{sys.executable}  -m jupyter nbextension enable --py widgetsnbextension
# !{sys.executable} -m pip install gmaps
# Out:
# zsh:1: parse error near `-m'
# zsh:1: parse error near `-m'
# zsh:1: parse error near `-m'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
g_key = "AIzaSyCE8r8vhtdU_vr2TywgqLD6zaFOXJ0m6cY"

# %%
weather_data = pd.read_csv("cities.csv")
                           
weather_data
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Bredasdorp           2      ZA  1605245069        61 -34.53   20.04
# 1              Abhā          20      SA  1605245353        82  18.22   42.51
# 2              Jalu          16      LY  1605245354        85  29.03   21.55
# 3          Sheridan           1      US  1605245354        67  44.83 -106.92
# 4         Road Town          40      VG  1605245142        86  18.42  -64.62
# ...             ...         ...     ...         ...       ...    ...     ...
# 1024       Severnyy           0      RU  1605245742       100  50.68   36.55
# 1025      Aginskoye           7      RU  1605245743        76  51.10  114.53
# 1026  Srednekolymsk          98      RU  1605245743        89  67.45  153.68
# 1027      Marrakesh          75      MA  1605245743        77  31.63   -8.01
# 1028        Yueyang           0      CN  1605245743        42  29.33  113.09
#
#       Max Temp  Wind Speed
# 0        72.00        1.01
# 1        62.60        4.70
# 2        60.46        6.24
# 3        26.01        4.70
# 4        80.01        5.99
# ...        ...         ...
# 1024     23.00        2.24
# 1025     34.59        5.64
# 1026    -13.13        1.25
# 1027     60.80        5.82
# 1028     74.01        9.75
#
# [1029 rows x 9 columns]

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)

# Store latitude and longitude in locations
locations = weather_data[["Lat", "Lng"]]

# Store Humidity in humidity
humidity = weather_data["Humidity"]

# %%
# Plot Heatmap
fig = gmaps.figure(center=(46.0, -5.0), zoom_level=2)
max_intensity = np.max(humidity)

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights = humidity, dissipating=False, max_intensity=100, point_radius=3)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
max_intensity
# Out:
# 100

# %%
# Narrow down the cities with wind speed less than 10 mph, cloudiness equals to 0 and max temp between 60 and 80
narrowed_city_df = weather_data.loc[(weather_data["Wind Speed"] <= 10) & (weather_data["Cloudiness"] == 0) & \
                                   (weather_data["Max Temp"] >= 70) & (weather_data["Max Temp"] <= 80)].dropna()

narrowed_city_df
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 30       Springbok           0      ZA  1605245107        19 -29.66   17.89
# 42       Morondava           0      MG  1605245361        65 -20.28   44.28
# 75        Yairipok           0      IN  1605245366        50  24.67   94.07
# 88            Esim           0      GH  1605245270        87   4.87   -2.24
# 120          Ibrā’           0      OM  1605245159        24  22.69   58.53
# 125      Hong Kong           0      HK  1605244926        36  22.29  114.16
# 171           Wuxi           0      CN  1605245087        45  31.57  120.29
# 207         Xishan           0      CN  1605245390        44  27.67  113.50
# 248         Bonthe           0      SL  1605245398        89   7.53  -12.51
# 252       Manicoré           0      BR  1605245399        94  -5.81  -61.30
# 262          Umluj           0      SA  1605245401        50  25.02   37.27
# 285       Kaffrine           0      SN  1605245412        21  14.11  -15.55
# 320      Takoradze           0      GH  1605245426        86   4.88   -1.76
# 359   Kruisfontein           0      ZA  1605245106        57 -34.00   24.73
# 424      Pingxiang           0      CN  1605245458        31  27.62  113.85
# 436        Tongren           0      CN  1605245464        42  27.72  109.19
# 453      Boa Vista           0      BR  1605245034        94   2.82  -60.67
# 493      Springbok           0      ZA  1605245107        19 -29.66   17.89
# 505      Morondava           0      MG  1605245361        65 -20.28   44.28
# 538       Yairipok           0      IN  1605245366        50  24.67   94.07
# 551           Esim           0      GH  1605245270        87   4.87   -2.24
# 583          Ibrā’           0      OM  1605245159        24  22.69   58.53
# 588      Hong Kong           0      HK  1605244926        36  22.29  114.16
# 634           Wuxi           0      CN  1605245087        45  31.57  120.29
# 670         Xishan           0      CN  1605245390        44  27.67  113.50
# 711         Bonthe           0      SL  1605245398        89   7.53  -12.51
# 715       Manicoré           0      BR  1605245399        94  -5.81  -61.30
# 725          Umluj           0      SA  1605245401        50  25.02   37.27
# 748       Kaffrine           0      SN  1605245412        21  14.11  -15.55
# 783      Takoradze           0      GH  1605245426        86   4.88   -1.76
# 822   Kruisfontein           0      ZA  1605245106        57 -34.00   24.73
# 887      Pingxiang           0      CN  1605245458        31  27.62  113.85
# 899        Tongren           0      CN  1605245464        42  27.72  109.19
# 916      Boa Vista           0      BR  1605245528        94   2.82  -60.67
# 941        Savalou           0      BJ  1605245722        50   7.93    1.98
# 982          Dosso           0      NE  1605245730        29  13.05    3.19
# 1028       Yueyang           0      CN  1605245743        42  29.33  113.09
#
#       Max Temp  Wind Speed
# 30       73.13        5.50
# 42       79.20        4.70
# 75       76.96        1.07
# 88       77.94        4.45
# 120      78.19        0.94
# 125      77.00        9.17
# 171      73.99        1.99
# 207      75.20        4.47
# 248      76.62        2.93
# 252      77.00        1.12
# 262      76.91        6.42
# 285      74.25        7.38
# 320      78.12        4.09
# 359      71.74        4.59
# 424      75.02        7.76
# 436      70.70        6.78
# 453      77.00        4.70
# 493      73.13        5.50
# 505      79.20        4.70
# 538      76.96        1.07
# 551      77.94        4.45
# 583      78.19        0.94
# 588      77.00        9.17
# 634      73.99        1.99
# 670      75.20        4.47
# 711      76.62        2.93
# 715      77.00        1.12
# 725      76.91        6.42
# 748      74.25        7.38
# 783      78.12        4.09
# 822      71.74        4.59
# 887      75.02        7.76
# 899      70.70        6.78
# 916      77.00        4.70
# 941      74.14        3.71
# 982      70.29        9.42
# 1028     74.01        9.75

# %%
# Create a hotel_df
hotel_df = narrowed_city_df.loc[:,["City","Country", "Lat", "Lng"]]

# Add a "Hotel Name" column to the DataFrame.
hotel_df["Hotel Name"] = ""

# Display the result
hotel_df
hotel_df.head()
# Out:
#           City Country    Lat    Lng Hotel Name
# 30   Springbok      ZA -29.66  17.89
# 42   Morondava      MG -20.28  44.28
# 75    Yairipok      IN  24.67  94.07
# 88        Esim      GH   4.87  -2.24
# 120      Ibrā’      OM  22.69  58.53

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}

# %%
for index, row in hotel_df.iterrows():
    # get city name, lat, lnt from df
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    
    # add keyword to params dict
    params["location"] = f"{lat},{lng}"

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    # save the hotel name to dataframe
    try:
        print(f"Closest hotel in {city_name} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']

    # if there is no hotel available, show missing field
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
    
    # Wait 1 sec to make another api request to avoid SSL Error
    #time.sleep(1)

# Print end of search once searching is completed
print("-------End of Search-------")
# Out:
# Retrieving Results for Index 30: Springbok.
# Closest hotel in Springbok is Springbok Inn by Country Hotels.
# ------------
# Retrieving Results for Index 42: Morondava.
# Closest hotel in Morondava is Kimony Resort Hotel.
# ------------
# Retrieving Results for Index 75: Yairipok.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 88: Esim.
# Closest hotel in Esim is Lou Moon Resort - Eco Luxury.
# ------------
# Retrieving Results for Index 120: Ibrā’.
# Closest hotel in Ibrā’ is Ibra Hotel.
# ------------
# Retrieving Results for Index 125: Hong Kong.
# Closest hotel in Hong Kong is The Peninsula Hong Kong.
# ------------
# Retrieving Results for Index 171: Wuxi.
# Closest hotel in Wuxi is Hyatt Regency Wuxi.
# ------------
# Retrieving Results for Index 207: Xishan.
# Closest hotel in Xishan is Dongfeng Hotel.
# ------------
# Retrieving Results for Index 248: Bonthe.
# Closest hotel in Bonthe is Bonthe Holiday Village.
# ------------
# Retrieving Results for Index 252: Manicoré.
# Closest hotel in Manicoré is Hotel Durval.
# ------------
# Retrieving Results for Index 262: Umluj.
# Closest hotel in Umluj is Shada Collection Mina Hotel.
# ------------
# Retrieving Results for Index 285: Kaffrine.
# Closest hotel in Kaffrine is Hotel de l'Auberge.
# ------------
# Retrieving Results for Index 320: Takoradze.
# Closest hotel in Takoradze is The Palms by Eagles.
# ------------
# Retrieving Results for Index 359: Kruisfontein.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 424: Pingxiang.
# Closest hotel in Pingxiang is Anmansen Boutique Hotel.
# ------------
# Retrieving Results for Index 436: Tongren.
# Closest hotel in Tongren is Wanshanhong Hotel.
# ------------
# Retrieving Results for Index 453: Boa Vista.
# Closest hotel in Boa Vista is Hotel Orla do Rio Branco.
# ------------
# Retrieving Results for Index 493: Springbok.
# Closest hotel in Springbok is Springbok Inn by Country Hotels.
# ------------
# Retrieving Results for Index 505: Morondava.
# Closest hotel in Morondava is Palissandre Cote Ouest resort & SPA.
# ------------
# Retrieving Results for Index 538: Yairipok.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 551: Esim.
# Closest hotel in Esim is Ankobra Beach.
# ------------
# Retrieving Results for Index 583: Ibrā’.
# Closest hotel in Ibrā’ is Ibra Hotel.
# ------------
# Retrieving Results for Index 588: Hong Kong.
# Closest hotel in Hong Kong is The Peninsula Hong Kong.
# ------------
# Retrieving Results for Index 634: Wuxi.
# Closest hotel in Wuxi is Hyatt Regency Wuxi.
# ------------
# Retrieving Results for Index 670: Xishan.
# Closest hotel in Xishan is Dongfeng Hotel.
# ------------
# Retrieving Results for Index 711: Bonthe.
# Closest hotel in Bonthe is Bonthe Holiday Village.
# ------------
# Retrieving Results for Index 715: Manicoré.
# Closest hotel in Manicoré is Hotel Durval.
# ------------
# Retrieving Results for Index 725: Umluj.
# Closest hotel in Umluj is Shada Collection Mina Hotel.
# ------------
# Retrieving Results for Index 748: Kaffrine.
# Closest hotel in Kaffrine is Hotel de l'Auberge.
# ------------
# Retrieving Results for Index 783: Takoradze.
# Closest hotel in Takoradze is Milgwen Hotel.
# ------------
# Retrieving Results for Index 822: Kruisfontein.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 887: Pingxiang.
# Closest hotel in Pingxiang is Anmansen Boutique Hotel.
# ------------
# Retrieving Results for Index 899: Tongren.
# Closest hotel in Tongren is Wanshanhong Hotel.
# ------------
# Retrieving Results for Index 916: Boa Vista.
# Closest hotel in Boa Vista is Hotel Orla do Rio Branco.
# ------------
# Retrieving Results for Index 941: Savalou.
# Closest hotel in Savalou is Hotel La Reference.
# ------------
# Retrieving Results for Index 982: Dosso.
# Closest hotel in Dosso is Hôtel Zigi.
# ------------
# Retrieving Results for Index 1028: Yueyang.
# Closest hotel in Yueyang is Pullman Hotel.
# ------------
# -------End of Search-------

# %%
hotel_df
# Out:
#               City Country    Lat     Lng                           Hotel Name
# 30       Springbok      ZA -29.66   17.89      Springbok Inn by Country Hotels
# 42       Morondava      MG -20.28   44.28                  Kimony Resort Hotel
# 75        Yairipok      IN  24.67   94.07
# 88            Esim      GH   4.87   -2.24         Lou Moon Resort - Eco Luxury
# 120          Ibrā’      OM  22.69   58.53                           Ibra Hotel
# 125      Hong Kong      HK  22.29  114.16              The Peninsula Hong Kong
# 171           Wuxi      CN  31.57  120.29                   Hyatt Regency Wuxi
# 207         Xishan      CN  27.67  113.50                       Dongfeng Hotel
# 248         Bonthe      SL   7.53  -12.51               Bonthe Holiday Village
# 252       Manicoré      BR  -5.81  -61.30                         Hotel Durval
# 262          Umluj      SA  25.02   37.27          Shada Collection Mina Hotel
# 285       Kaffrine      SN  14.11  -15.55                   Hotel de l'Auberge
# 320      Takoradze      GH   4.88   -1.76                  The Palms by Eagles
# 359   Kruisfontein      ZA -34.00   24.73
# 424      Pingxiang      CN  27.62  113.85              Anmansen Boutique Hotel
# 436        Tongren      CN  27.72  109.19                    Wanshanhong Hotel
# 453      Boa Vista      BR   2.82  -60.67             Hotel Orla do Rio Branco
# 493      Springbok      ZA -29.66   17.89      Springbok Inn by Country Hotels
# 505      Morondava      MG -20.28   44.28  Palissandre Cote Ouest resort & SPA
# 538       Yairipok      IN  24.67   94.07
# 551           Esim      GH   4.87   -2.24                        Ankobra Beach
# 583          Ibrā’      OM  22.69   58.53                           Ibra Hotel
# 588      Hong Kong      HK  22.29  114.16              The Peninsula Hong Kong
# 634           Wuxi      CN  31.57  120.29                   Hyatt Regency Wuxi
# 670         Xishan      CN  27.67  113.50                       Dongfeng Hotel
# 711         Bonthe      SL   7.53  -12.51               Bonthe Holiday Village
# 715       Manicoré      BR  -5.81  -61.30                         Hotel Durval
# 725          Umluj      SA  25.02   37.27          Shada Collection Mina Hotel
# 748       Kaffrine      SN  14.11  -15.55                   Hotel de l'Auberge
# 783      Takoradze      GH   4.88   -1.76                        Milgwen Hotel
# 822   Kruisfontein      ZA -34.00   24.73
# 887      Pingxiang      CN  27.62  113.85              Anmansen Boutique Hotel
# 899        Tongren      CN  27.72  109.19                    Wanshanhong Hotel
# 916      Boa Vista      BR   2.82  -60.67             Hotel Orla do Rio Branco
# 941        Savalou      BJ   7.93    1.98                   Hotel La Reference
# 982          Dosso      NE  13.05    3.19                           Hôtel Zigi
# 1028       Yueyang      CN  29.33  113.09                        Pullman Hotel

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
#hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer and info box content ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Add the layer to the map
fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
